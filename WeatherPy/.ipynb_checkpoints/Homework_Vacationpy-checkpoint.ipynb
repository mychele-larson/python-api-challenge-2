# %% [markdown]
# ## Vacationpy Homework

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import gmaps
import os
from pprint import pprint

# Import API key
from api_key import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
vacation_data = pd.read_csv("data\weather_data.csv")
vacation_data.head(10)
# Out:
#    city           City Country  Latitude  Longitude  Max Temperature (F)  \
# 0     0      Hithadhoo      MV   -0.6000    73.0833                80.92
# 1     1         Albany      US   42.6001   -73.9662                72.54
# 2     2  Mar del Plata      AR  -38.0023   -57.5575                77.83
# 3     3       Nuristan      AF   35.3000    70.8333                23.81
# 4     4     Mossamedes      AO  -15.1961    12.1522                70.23
# 5     5      Busselton      AU  -33.6500   115.3333                57.87
# 6     6   Quatre Cocos      MU  -20.2078    57.7625                73.09
# 7     7   Punta Arenas      CL  -53.1500   -70.9167                64.11
# 8     8       Khatanga      RU   71.9667   102.5000               -20.99
# 9     9   Ponta do Sol      PT   32.6667   -17.1000                72.01
#
#    Humidity  Cloudiness  Windspeed (mph)        Date
# 0        77          42             9.40  1667761301
# 1        80         100             1.99  1667760858
# ...

# %%
# Remove extra column and reorganize
vacation_data_reorg = vacation_data.rename(columns={"City": "City", "Country": "Country", "Latitude": "Latitude", "Longitude": "Longitude",
                                                    "Max Temperature (F)": "Max Temp (F)", "Humidity": "Humidity %", "Cloudiness": "Clouds", "Windspeed (mph)": "Windspeed (mph)"})
vacation_data_reorg.head(10)
# Out:
#    city           City Country  Latitude  Longitude  Max Temp (F)  Humidity %  \
# 0     0      Hithadhoo      MV   -0.6000    73.0833         80.92          77
# 1     1         Albany      US   42.6001   -73.9662         72.54          80
# 2     2  Mar del Plata      AR  -38.0023   -57.5575         77.83          84
# 3     3       Nuristan      AF   35.3000    70.8333         23.81          92
# 4     4     Mossamedes      AO  -15.1961    12.1522         70.23          65
# 5     5      Busselton      AU  -33.6500   115.3333         57.87          80
# 6     6   Quatre Cocos      MU  -20.2078    57.7625         73.09          73
# 7     7   Punta Arenas      CL  -53.1500   -70.9167         64.11          45
# 8     8       Khatanga      RU   71.9667   102.5000        -20.99         100
# 9     9   Ponta do Sol      PT   32.6667   -17.1000         72.01          88
#
#    Clouds  Windspeed (mph)        Date
# 0      42             9.40  1667761301
# ...

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps using URL
units = "imperial"
city = ["City"]
gmaps_url = "https://www.googleapis.com/geolocation/v1/geolocate?key=[g_key]"
response_json = requests.get(gmaps_url).json()
pprint(response_json)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# c:\Users\myche\Anaconda_updated\lib\site-packages\requests\models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# c:\Users\myche\Anaconda_updated\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# c:\Users\myche\Anaconda_updated\lib\json\decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# ...
